# %% [markdown]
# 10 most populous neighborhoods in Atlanta and their population and coordinates:

# %%
import pandas as pd
import numpy as np


data = {
    "Neighborhood": ["Midtown", "Downtown", "Old Fourth Ward", "North Buckhead", "Pine Hills",
                     "Morningside/Lenox Park", "Virginia-Highland", "Grant Park", "Georgia Tech", "Kirkwood"],
    "Population": [16569, 13411, 10505, 8270, 8033, 8030, 7800, 6771, 6607, 5897],
    "NPU": ["E", "M", "M", "B", "B", "F", "F", "W", "E", "O"]
}

df = pd.DataFrame(data)
display(df)
# Out:
#              Neighborhood  Population NPU
# 0                 Midtown       16569   E
# 1                Downtown       13411   M
# 2         Old Fourth Ward       10505   M
# 3          North Buckhead        8270   B
# 4              Pine Hills        8033   B
# 5  Morningside/Lenox Park        8030   F
# 6       Virginia-Highland        7800   F
# 7              Grant Park        6771   W
# 8            Georgia Tech        6607   E
# 9                Kirkwood        5897   O

# %%
# !pip install googlemaps

import googlemaps
import pandas as pd
from geopy.geocoders import GoogleV3

# Enter your own API key
# Obtain a free Google Maps API key from your Google Cloud account
# Initialize the Google Maps client with your API key
geolocator = GoogleV3(api_key='AIzaSyBmBlB-0f44VBhhQB3eRVAJChi7Y4H8GKM')
gmaps = googlemaps.Client(key='AIzaSyBmBlB-0f44VBhhQB3eRVAJChi7Y4H8GKM')
# Out:
# Collecting googlemaps
#   Downloading googlemaps-4.10.0.tar.gz (33 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests<3.0,>=2.20.0 in /usr/local/lib/python3.11/dist-packages (from googlemaps) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0,>=2.20.0->googlemaps) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0,>=2.20.0->googlemaps) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0,>=2.20.0->googlemaps) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0,>=2.20.0->googlemaps) (2025.1.31)
# Building wheels for collected packages: googlemaps
#   Building wheel for googlemaps (setup.py) ... done
#   Created wheel for googlemaps: filename=googlemaps-4.10.0-py3-none-any.whl size=40715 sha256=bbf7bb7455e8b126b25158ddb399aff9cedf4f4932c8b2940585aa546faa142b
#   Stored in directory: /root/.cache/pip/wheels/f1/09/77/3cc2f5659cbc62341b30f806aca2b25e6a26c351daa5b1f49a
# Successfully built googlemaps
# Installing collected packages: googlemaps
# Successfully installed googlemaps-4.10.0

# %%
# Function to get geocode for a location
def get_geocode(location, city="Atlanta", state="GA", country="USA"):
    location_query = f"{location}, {city}, {state}, {country}"
    coords = geolocator.geocode(location_query)
    return round(coords.latitude, 4), round(coords.longitude, 4)

# %%
# Apply geocode function to DataFrame
df[['Latitude', 'Longitude']] = df['Neighborhood'].apply(lambda x: pd.Series(get_geocode(x)))

# %%
df
# Out:
#              Neighborhood  Population NPU  Latitude  Longitude
# 0                 Midtown       16569   E   33.7833   -84.3831
# 1                Downtown       13411   M   33.7557   -84.3884
# 2         Old Fourth Ward       10505   M   33.7640   -84.3720
# 3          North Buckhead        8270   B   33.8527   -84.3654
# 4              Pine Hills        8033   B   33.8375   -84.3516
# 5  Morningside/Lenox Park        8030   F   33.7962   -84.3595
# 6       Virginia-Highland        7800   F   33.7817   -84.3635
# 7              Grant Park        6771   W   33.7372   -84.3682
# 8            Georgia Tech        6607   E   33.7756   -84.3963
# 9                Kirkwood        5897   O   33.7533   -84.3262

# %% [markdown]
# # not weighted by population

# %% [markdown]
# ## Haversine distance

# %%
from geopy.distance import great_circle
# Function to calculate haversine distance
def haversine(lat1, lon1, lat2, lon2):
    return great_circle((lat1, lon1), (lat2, lon2)).miles

# %%
from scipy.optimize import minimize
import numpy as np

# Extract latitude and longitude as a NumPy array
locations = df[['Latitude', 'Longitude']].values

# Function to calculate the total distance from a given point to all locations
def total_haversine_distance(center):
    lat_center, lon_center = center  # Unpack the candidate location
    total_distance = sum(
        great_circle((lat, lon), (lat_center, lon_center)).miles
        for lat, lon in locations
    )
    return total_distance  # The goal is to minimize this total distance

# Use the mean latitude and longitude as the starting point for optimization
initial_guess = np.mean(locations, axis=0)

# Find the optimal location that minimizes the total Haversine distance
result = minimize(total_haversine_distance, initial_guess, method='Nelder-Mead')

# Extract the best location found
optimal_lat, optimal_lon = result.x
print(f"Optimal Pickup Location: ({optimal_lat:.4f}, {optimal_lon:.4f})")
# Out:
# Optimal Pickup Location: (33.7794, -84.3702)

# %% [markdown]
# ## Driving Distance

# %%
import googlemaps
from googlemaps.exceptions import ApiError

# Function to get the driving distance between two points with error handling
def get_driving_distance(origin, destination):
    try:
        result = gmaps.distance_matrix(origin, destination, mode="driving")
        # Check if the API returns valid results
        if result['status'] == 'OK':
            distance = result['rows'][0]['elements'][0]['distance']['value']
            return distance
        else:
            print(f"Error in API response: {result.get('status')}")
            return None
    except ApiError as e:
        print(f"API Request Error: {e}")
        return None
    except Exception as e:
        print(f"Unexpected error: {e}")
        return None

# Function to calculate total distance for a given parcel location (no population weighting)
def total_distance_for_location(parcel_lat, parcel_lon, df):
    total_distance = 0
    for idx, row in df.iterrows():
        origin = (row['Latitude'], row['Longitude'])  # Neighborhood coordinates
        destination = (parcel_lat, parcel_lon)  # Parcel pickup location
        distance = get_driving_distance(origin, destination)
        if distance is not None:
            total_distance += distance  # Simply sum up the distances without population weighting
    return total_distance

# Function to find the optimal location using grid search
def find_optimal_location(df):
    # Define the range of latitudes and longitudes to search over (smaller grid for higher precision)
    latitudes = np.arange(33.70, 33.90, 0.001)  # 0.001 step for higher precision
    longitudes = np.arange(-84.40, -84.30, 0.001)  # 0.001 step for higher precision

    best_location = None
    min_distance = float('inf')

    # Grid Search: Check all points in the grid
    for lat in latitudes:
        for lon in longitudes:
            total_distance = total_distance_for_location(lat, lon, df)
            if total_distance < min_distance:
                min_distance = total_distance
                best_location = (lat, lon)

    return best_location  # Only return the best location

# Example of how to run the function
best_location = find_optimal_location(df)

# Print the best location with coordinates rounded to 6 decimal places
if best_location:
    best_lat, best_lon = best_location
    print(f"Best Location: ({best_lat:.3f}, {best_lon:.3f})")
else:
    print("No optimal location found.")
# Out:
# Best Location: (33.782000, -84.368000)

# %%
# not trying to run the iteration again. The best location should be round to 3 decimal

# %% [markdown]
# # weighted by population

# %% [markdown]
# ## haversine distance

# %%
# Extract latitude, longitude, and population as NumPy arrays
locations = df[['Latitude', 'Longitude']].values
populations = df['Population'].values  # Extract population column

# Function to calculate the weighted total distance from a given point to all locations
def weighted_haversine_distance(center):
    lat_center, lon_center = center  # Unpack the candidate location
    total_distance = sum(
        pop * great_circle((lat, lon), (lat_center, lon_center)).miles
        for (lat, lon), pop in zip(locations, populations)
    )
    return total_distance  # The goal is to minimize this total weighted distance

# Use the weighted mean latitude and longitude as the starting point
weighted_lat = np.average(df['Latitude'], weights=df['Population'])
weighted_lon = np.average(df['Longitude'], weights=df['Population'])
initial_guess = np.array([weighted_lat, weighted_lon])

# Find the optimal location that minimizes the weighted total Haversine distance
result = minimize(weighted_haversine_distance, initial_guess, method='Nelder-Mead')

# Extract the best location found
optimal_lat, optimal_lon = result.x
print(f"Optimal Pickup Location: ({optimal_lat:.4f}, {optimal_lon:.4f})")
# Out:
# Optimal Pickup Location: (33.7791, -84.3764)

# %% [markdown]
# ## Driving distance

# %%
# Function to get the driving distance between two points with error handling
def get_driving_distance(origin, destination):
    try:
        result = gmaps.distance_matrix(origin, destination, mode="driving")
        if result['status'] == 'OK':
            distance = result['rows'][0]['elements'][0]['distance']['value']  # Distance in meters
            return distance
        else:
            print(f"Error in API response: {result.get('status')}")
            return None
    except ApiError as e:
        print(f"API Request Error: {e}")
        return None
    except Exception as e:
        print(f"Unexpected error: {e}")
        return None

# Function to calculate total weighted distance for a given parcel location
def weighted_total_distance(parcel_lat, parcel_lon, df):
    total_distance = 0
    total_population = df['Population'].sum()  # Normalize population weights

    for _, row in df.iterrows():
        origin = (row['Latitude'], row['Longitude'])
        destination = (parcel_lat, parcel_lon)
        distance = get_driving_distance(origin, destination)
        if distance is not None:
            total_distance += (row['Population'] / total_population) * distance  # Weight by population

    return total_distance

# Function to find the optimal location using grid search
def find_optimal_weighted_location(df):
    # Define the range of latitudes and longitudes to search over
    latitudes = np.arange(33.70, 33.90, 0.01)
    longitudes = np.arange(-84.40, -84.30, 0.01)

    best_location = None
    min_distance = float('inf')

    # Grid Search: Check all points in the grid
    for lat in latitudes:
        for lon in longitudes:
            total_distance = weighted_total_distance(lat, lon, df)
            if total_distance < min_distance:
                min_distance = total_distance
                best_location = (lat, lon)

    return best_location

# Example execution
best_location = find_optimal_weighted_location(df)

if best_location:
    best_lat, best_lon = best_location
    print(f"Best Weighted Location: ({best_lat:.2f}, {best_lon:.2f})")
else:
    print("No optimal location found.")
# Out:
# Best Weighted Location: (33.78, -84.37)

# %% [markdown]
# # address and show on the map

# %%
# Function to get address from latitude and longitude
def get_address_from_coordinates(lat, lon):
    try:
        result = gmaps.reverse_geocode((lat, lon))  # Reverse geocoding
        if result:
            return result[0]['formatted_address']  # Extract formatted address
        else:
            return "No address found"
    except Exception as e:
        return f"Error: {e}"

address_h = get_address_from_coordinates(33.7794, -84.3702)
address_d = get_address_from_coordinates(33.782, -84.368)
address_pop_h = get_address_from_coordinates(33.7791, -84.3764)
address_pop_d = get_address_from_coordinates(33.78, -84.37)
print(f"Optimal Pickup Location Address using Haversine Distance: {address_h}")
print(f"Optimal Pickup Location Address using Driving Distance: {address_d}")
print(f"Optimal Pickup Location Address using Haversine Distance weighted by Population: {address_pop_h}")
print(f"Optimal Pickup Location Address using Driving Distance weighted by Population: {address_pop_d}")
# Out:
# Optimal Pickup Location Address using Haversine Distance: 517 8th St NE, Atlanta, GA 30308, USA
# Optimal Pickup Location Address using Driving Distance: 1011 Kanuga St NE, Atlanta, GA 30306, USA
# Optimal Pickup Location Address using Haversine Distance weighted by Population: 343 8th St NE, Atlanta, GA 30309, USA
# Optimal Pickup Location Address using Driving Distance weighted by Population: 930 Monroe Dr NE, Atlanta, GA 30308, USA

# %%
import folium

# Function to plot the map
def plot_map(df, best_location, title):
    avg_lat = df['Latitude'].mean()
    avg_lon = df['Longitude'].mean()
    map_center = [avg_lat, avg_lon]

    m = folium.Map(location=map_center, zoom_start=12, width="50%", height="500px")


    # Add markers for each neighborhood
    for _, row in df.iterrows():
        folium.CircleMarker(
            location=[row['Latitude'], row['Longitude']],
            radius=np.sqrt(row['Population']) / 5,  # Adjust size based on population
            color="blue",
            fill=True,
            fill_color="blue",
            fill_opacity=0.5,
            popup=f"{row['Neighborhood']} (Pop: {row['Population']})"
        ).add_to(m)

    # Add a marker for the best location
    if best_location:
        best_lat, best_lon = best_location
        folium.Marker(
            location=[best_lat, best_lon],
            popup=f"{title}\n({best_lat:.6f}, {best_lon:.6f})",
            icon=folium.Icon(color="red", icon="cloud"),
        ).add_to(m)

    return m

# %%
from IPython.display import display

# Function to get address from coordinates
def get_address_from_coordinates(lat, lon):
    try:
        result = gmaps.reverse_geocode((lat, lon))  # Reverse geocoding
        if result:
            return result[0]['formatted_address']  # Extract formatted address
        else:
            return "No address found"
    except Exception as e:
        return f"Error: {e}"



# Coordinates for different optimal locations
coords = {
    "Haversine Distance": (33.7794, -84.3702),
    "Driving Distance": (33.782, -84.368),
    "Haversine Weighted by Population": (33.7791, -84.3764),
    "Driving Weighted by Population": (33.78, -84.37),
}

# Generate maps
maps = {name: plot_map(df, (lat, lon), name) for name, (lat, lon) in coords.items()}


# Save and display all maps properly in Colab
for name, m in maps.items():
    filename = f"optimal_location_{name.replace(' ', '_').lower()}.html"
    m.save(filename)
    print(f"Map saved: {filename}")
    display(m)  # This ensures the map displays correctly in Colab
# Out:
# Map saved: optimal_location_haversine_distance.html
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cc8d434b2702dbada75c2cf6112f25cb {
#                     position: relative;
#                     width: 50.0%;
#                     height: 500.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cc8d434b2702dbada75c2cf6112f25cb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cc8d434b2702dbada75c2cf6112f25cb = L.map(
#                 &quot;map_cc8d434b2702dbada75c2cf6112f25cb&quot;,
#                 {
#                     center: [33.78372, -84.36742],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2335bef866351f3fab2288ec615159d5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2335bef866351f3fab2288ec615159d5.addTo(map_cc8d434b2702dbada75c2cf6112f25cb);
#
#
#             var circle_marker_cca9bb1e4e720f306acaa5c5de80d837 = L.circleMarker(
#                 [33.7833, -84.3831],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 25.74412554350992, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_cc8d434b2702dbada75c2cf6112f25cb);
#
#
#         var popup_0029a87c9edfbcafde891ff1100d86ce = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3723e8af4af667b7cd823674db6da0c9 = $(`&lt;div id=&quot;html_3723e8af4af667b7cd823674db6da0c9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Midtown (Pop: 16569)&lt;/div&gt;`)[0];
#                 popup_0029a87c9edfbcafde891ff1100d86ce.setContent(html_3723e8af4af667b7cd823674db6da0c9);
#
#
#
#         circle_marker_cca9bb1e4e720f306acaa5c5de80d837.bindPopup(popup_0029a87c9edfbcafde891ff1100d86ce)
#         ;
#
#
#
#
#             var circle_marker_850cdbcc8f92e828cca091d958aac443 = L.circleMarker(
#                 [33.7557, -84.3884],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 23.161174408911133, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_cc8d434b2702dbada75c2cf6112f25cb);
#
#
#         var popup_59be20e8ee30c2d5883f05d52b5e6b6a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_207b43672ee7ae5d0406488ae1cad1d5 = $(`&lt;div id=&quot;html_207b43672ee7ae5d0406488ae1cad1d5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Downtown (Pop: 13411)&lt;/div&gt;`)[0];
#                 popup_59be20e8ee30c2d5883f05d52b5e6b6a.setContent(html_207b43672ee7ae5d0406488ae1cad1d5);
#
#
#
#         circle_marker_850cdbcc8f92e828cca091d958aac443.bindPopup(popup_59be20e8ee30c2d5883f05d52b5e6b6a)
#         ;
#
#
#
#
#             var circle_marker_475d00b5dd46bcc2bdd9f0a308d36216 = L.circleMarker(
#                 [33.764, -84.372],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 20.498780451529306, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_cc8d434b2702dbada75c2cf6112f25cb);
#
#
#         var popup_f9cab04a789c622edddd57f168cbce96 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ec89368ccdfdf25bfe1f0a0a60460b09 = $(`&lt;div id=&quot;html_ec89368ccdfdf25bfe1f0a0a60460b09&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Old Fourth Ward (Pop: 10505)&lt;/div&gt;`)[0];
#                 popup_f9cab04a789c622edddd57f168cbce96.setContent(html_ec89368ccdfdf25bfe1f0a0a60460b09);
#
#
#
#         circle_marker_475d00b5dd46bcc2bdd9f0a308d36216.bindPopup(popup_f9cab04a789c622edddd57f168cbce96)
#         ;
#
#
#
#
#             var circle_marker_703725f93dd154a3ffc4cb2dd5b41cf4 = L.circleMarker(
#                 [33.8527, -84.3654],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quo
# Map saved: optimal_location_driving_distance.html
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_989f2ecebac6c0a60d4cf02183db4fe2 {
#                     position: relative;
#                     width: 50.0%;
#                     height: 500.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_989f2ecebac6c0a60d4cf02183db4fe2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_989f2ecebac6c0a60d4cf02183db4fe2 = L.map(
#                 &quot;map_989f2ecebac6c0a60d4cf02183db4fe2&quot;,
#                 {
#                     center: [33.78372, -84.36742],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_73fab90d00c7668d006b8bbdc61a6cc3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_73fab90d00c7668d006b8bbdc61a6cc3.addTo(map_989f2ecebac6c0a60d4cf02183db4fe2);
#
#
#             var circle_marker_27af9b30ec4c18fd56e3bc57a4e3fff9 = L.circleMarker(
#                 [33.7833, -84.3831],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 25.74412554350992, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_989f2ecebac6c0a60d4cf02183db4fe2);
#
#
#         var popup_fe97ef251d03bc3478687205f39fa5fd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_90bd78a24b90e3caaf31984a6fd9a565 = $(`&lt;div id=&quot;html_90bd78a24b90e3caaf31984a6fd9a565&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Midtown (Pop: 16569)&lt;/div&gt;`)[0];
#                 popup_fe97ef251d03bc3478687205f39fa5fd.setContent(html_90bd78a24b90e3caaf31984a6fd9a565);
#
#
#
#         circle_marker_27af9b30ec4c18fd56e3bc57a4e3fff9.bindPopup(popup_fe97ef251d03bc3478687205f39fa5fd)
#         ;
#
#
#
#
#             var circle_marker_2e00a11d13e3e8df01889909e936d56c = L.circleMarker(
#                 [33.7557, -84.3884],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 23.161174408911133, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_989f2ecebac6c0a60d4cf02183db4fe2);
#
#
#         var popup_51f7e6fc0b275e6de8bf810a0e9bbafd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_352e04e1feeb15c592f8ad82de69026c = $(`&lt;div id=&quot;html_352e04e1feeb15c592f8ad82de69026c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Downtown (Pop: 13411)&lt;/div&gt;`)[0];
#                 popup_51f7e6fc0b275e6de8bf810a0e9bbafd.setContent(html_352e04e1feeb15c592f8ad82de69026c);
#
#
#
#         circle_marker_2e00a11d13e3e8df01889909e936d56c.bindPopup(popup_51f7e6fc0b275e6de8bf810a0e9bbafd)
#         ;
#
#
#
#
#             var circle_marker_2ffddcb761afb47dd46ff45094a3e068 = L.circleMarker(
#                 [33.764, -84.372],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 20.498780451529306, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_989f2ecebac6c0a60d4cf02183db4fe2);
#
#
#         var popup_18f5154c7fc8bdea1fb0f39a7ac8a513 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_46dc65ec8357ce0b559b0194a9d65ea7 = $(`&lt;div id=&quot;html_46dc65ec8357ce0b559b0194a9d65ea7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Old Fourth Ward (Pop: 10505)&lt;/div&gt;`)[0];
#                 popup_18f5154c7fc8bdea1fb0f39a7ac8a513.setContent(html_46dc65ec8357ce0b559b0194a9d65ea7);
#
#
#
#         circle_marker_2ffddcb761afb47dd46ff45094a3e068.bindPopup(popup_18f5154c7fc8bdea1fb0f39a7ac8a513)
#         ;
#
#
#
#
#             var circle_marker_f23bd9b53b40dc29abdb74054a532491 = L.circleMarker(
#                 [33.8527, -84.3654],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quo
# Map saved: optimal_location_haversine_weighted_by_population.html
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_438361d93cb22b35371f48f49b52a801 {
#                     position: relative;
#                     width: 50.0%;
#                     height: 500.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_438361d93cb22b35371f48f49b52a801&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_438361d93cb22b35371f48f49b52a801 = L.map(
#                 &quot;map_438361d93cb22b35371f48f49b52a801&quot;,
#                 {
#                     center: [33.78372, -84.36742],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3167abdcd9cf5f207e63ab7ecb509a60 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3167abdcd9cf5f207e63ab7ecb509a60.addTo(map_438361d93cb22b35371f48f49b52a801);
#
#
#             var circle_marker_268183e05009b63f4864a6026add21dd = L.circleMarker(
#                 [33.7833, -84.3831],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 25.74412554350992, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_438361d93cb22b35371f48f49b52a801);
#
#
#         var popup_c1fb15f23160cdd14cf8662b1ddf32d5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_12e94f166d04aae61f584b50908d5eb9 = $(`&lt;div id=&quot;html_12e94f166d04aae61f584b50908d5eb9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Midtown (Pop: 16569)&lt;/div&gt;`)[0];
#                 popup_c1fb15f23160cdd14cf8662b1ddf32d5.setContent(html_12e94f166d04aae61f584b50908d5eb9);
#
#
#
#         circle_marker_268183e05009b63f4864a6026add21dd.bindPopup(popup_c1fb15f23160cdd14cf8662b1ddf32d5)
#         ;
#
#
#
#
#             var circle_marker_dccbabf979e6755e1568d3a887af14dc = L.circleMarker(
#                 [33.7557, -84.3884],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 23.161174408911133, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_438361d93cb22b35371f48f49b52a801);
#
#
#         var popup_f01efb2954881c933bf6f2eb7f0fbe65 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_160a77f727f85eb1fdc2125c646b2897 = $(`&lt;div id=&quot;html_160a77f727f85eb1fdc2125c646b2897&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Downtown (Pop: 13411)&lt;/div&gt;`)[0];
#                 popup_f01efb2954881c933bf6f2eb7f0fbe65.setContent(html_160a77f727f85eb1fdc2125c646b2897);
#
#
#
#         circle_marker_dccbabf979e6755e1568d3a887af14dc.bindPopup(popup_f01efb2954881c933bf6f2eb7f0fbe65)
#         ;
#
#
#
#
#             var circle_marker_217d0a81055dc92ff980ea96e12b6b1a = L.circleMarker(
#                 [33.764, -84.372],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 20.498780451529306, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_438361d93cb22b35371f48f49b52a801);
#
#
#         var popup_140062b3f227c4ff20d3946c1a1cd908 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_303cc6aa72a8cffd426c2dfa0f08ac35 = $(`&lt;div id=&quot;html_303cc6aa72a8cffd426c2dfa0f08ac35&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Old Fourth Ward (Pop: 10505)&lt;/div&gt;`)[0];
#                 popup_140062b3f227c4ff20d3946c1a1cd908.setContent(html_303cc6aa72a8cffd426c2dfa0f08ac35);
#
#
#
#         circle_marker_217d0a81055dc92ff980ea96e12b6b1a.bindPopup(popup_140062b3f227c4ff20d3946c1a1cd908)
#         ;
#
#
#
#
#             var circle_marker_146ce8422779ea31d04c7a1c7bc20680 = L.circleMarker(
#                 [33.8527, -84.3654],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quo
# Map saved: optimal_location_driving_weighted_by_population.html
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a6a160e5f04afa96471200b9b63d2751 {
#                     position: relative;
#                     width: 50.0%;
#                     height: 500.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a6a160e5f04afa96471200b9b63d2751&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a6a160e5f04afa96471200b9b63d2751 = L.map(
#                 &quot;map_a6a160e5f04afa96471200b9b63d2751&quot;,
#                 {
#                     center: [33.78372, -84.36742],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_17368740e5cde83826eec1c930a221a5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_17368740e5cde83826eec1c930a221a5.addTo(map_a6a160e5f04afa96471200b9b63d2751);
#
#
#             var circle_marker_f77dfbd184fe0289417f1749b3f74740 = L.circleMarker(
#                 [33.7833, -84.3831],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 25.74412554350992, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a6a160e5f04afa96471200b9b63d2751);
#
#
#         var popup_711c01708e189f22c43587e7ce3cd47f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9b49cfc803f2563fb975e202c5a68bb6 = $(`&lt;div id=&quot;html_9b49cfc803f2563fb975e202c5a68bb6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Midtown (Pop: 16569)&lt;/div&gt;`)[0];
#                 popup_711c01708e189f22c43587e7ce3cd47f.setContent(html_9b49cfc803f2563fb975e202c5a68bb6);
#
#
#
#         circle_marker_f77dfbd184fe0289417f1749b3f74740.bindPopup(popup_711c01708e189f22c43587e7ce3cd47f)
#         ;
#
#
#
#
#             var circle_marker_3b2f25e8194ff354cdb49e256b9b5bb3 = L.circleMarker(
#                 [33.7557, -84.3884],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 23.161174408911133, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a6a160e5f04afa96471200b9b63d2751);
#
#
#         var popup_bd4cca8448df4c7907eb0ef9f5823cb6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1d5a655c776c0d6cd2a601df4c53ab41 = $(`&lt;div id=&quot;html_1d5a655c776c0d6cd2a601df4c53ab41&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Downtown (Pop: 13411)&lt;/div&gt;`)[0];
#                 popup_bd4cca8448df4c7907eb0ef9f5823cb6.setContent(html_1d5a655c776c0d6cd2a601df4c53ab41);
#
#
#
#         circle_marker_3b2f25e8194ff354cdb49e256b9b5bb3.bindPopup(popup_bd4cca8448df4c7907eb0ef9f5823cb6)
#         ;
#
#
#
#
#             var circle_marker_18f830b6ffe0a05857e30b68869b2158 = L.circleMarker(
#                 [33.764, -84.372],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 20.498780451529306, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a6a160e5f04afa96471200b9b63d2751);
#
#
#         var popup_1cf475aea51393ef358a9e8ab4e8a4c3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b4b5143b2e5ee6f74231879b4a50e3c8 = $(`&lt;div id=&quot;html_b4b5143b2e5ee6f74231879b4a50e3c8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Old Fourth Ward (Pop: 10505)&lt;/div&gt;`)[0];
#                 popup_1cf475aea51393ef358a9e8ab4e8a4c3.setContent(html_b4b5143b2e5ee6f74231879b4a50e3c8);
#
#
#
#         circle_marker_18f830b6ffe0a05857e30b68869b2158.bindPopup(popup_1cf475aea51393ef358a9e8ab4e8a4c3)
#         ;
#
#
#
#
#             var circle_marker_379221c06bfeaafeeb17f41c16e86b58 = L.circleMarker(
#                 [33.8527, -84.3654],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quo
